# %% [markdown]
# # Student Performance - Exploratory Data Analysis
# Analyzing correlations between study time, absences, and final grades.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('../data/raw/student_data_v2.csv')
sns.heatmap(df.corr(), annot=True)
